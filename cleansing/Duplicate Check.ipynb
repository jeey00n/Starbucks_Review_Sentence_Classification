# %%
import pandas as pd
kakao_reviews = pd.read_csv('./dataset/kakao_reviews_total.csv')
kakao_reviews
# Out:
#                                                iter_num          store  \
# 0                                                     0      스타벅스 강남R점
# 1                                                     1      스타벅스 강남R점
# 2                                                     2      스타벅스 강남R점
# 3                                                     3      스타벅스 강남R점
# 4                                                     4      스타벅스 강남R점
# ...                                                 ...            ...
# 6607                                                  4   스타벅스 마리오아울렛점
# 6608            이름설정ㅋㅋㅋㅋㅋㅋㅋㅋ ㅋㅋㅋㅋㅋㅋ젤우껴따ㅋㅋㅋㅋ 끝끝내 폰업뎃 완료!            NaN
# 6609  내가 갔던 스벅중에 젤 좋아하는곳 비교적 조용하고 중앙을 제외한 나머지부분이 천장이...            NaN
# 6610                                                  0  스타벅스 대치삼성프라자점
# 6611                                                  1  스타벅스 대치삼성프라자점
#
#              time  rating                                             review
# ...

# %%
kakao_reviews.dropna(axis=0, inplace=True)
kakao_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6255 entries, 0 to 6611
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   iter_num  6255 non-null   object
#  1   store     6255 non-null   object
#  2   time      6255 non-null   object
#  3   rating    6255 non-null   float64
#  4   review    6255 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 293.2+ KB

# %%
naver_reviews = pd.read_csv('./dataset/naver_store1_3.csv')
naver_reviews
# Out:
#         Unnamed: 0  user          store        time  rating  \
# 0                0     1  스타벅스 역삼아레나빌딩점  2021.04.09     3.5
# 1                1     2  스타벅스 역삼아레나빌딩점  2021.04.06     5.0
# 2                2     4  스타벅스 역삼아레나빌딩점  2021.04.01     5.0
# 3                3     5  스타벅스 역삼아레나빌딩점  2021.03.27     5.0
# 4                4     6  스타벅스 역삼아레나빌딩점  2021.03.24     5.0
# ...            ...   ...            ...         ...     ...
# 123525        3975   104      스타벅스 중화역점  2020.12.25     5.0
# 123526        3976   126      스타벅스 중화역점  2020.12.23     5.0
# 123527        3977   130      스타벅스 중화역점  2020.12.23     4.0
# 123528        3978   131      스타벅스 중화역점  2020.12.23     4.0
# 123529        3979   132      스타벅스 중화역점  2020.12.22     4.0
#
#                                   review   site
# 0                                  친절해요~  naver
# 1                                  역시 스벅  naver
# 2                                   친절해요  naver
# 3                             넓고 깻끗해서좋아요  naver
# ...

# %%
naver_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123530 entries, 0 to 123529
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  123530 non-null  int64
#  1   user        123530 non-null  int64
#  2   store       123530 non-null  object
#  3   time        123530 non-null  object
#  4   rating      123530 non-null  float64
#  5   review      122990 non-null  object
#  6   site        123530 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.6+ MB

# %%
naver_reviews.dropna(axis=0, inplace=True)
naver_reviews.drop('Unnamed: 0', axis = 1, inplace = True)
naver_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122990 entries, 0 to 123529
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   user    122990 non-null  int64
#  1   store   122990 non-null  object
#  2   time    122990 non-null  object
#  3   rating  122990 non-null  float64
#  4   review  122990 non-null  object
#  5   site    122990 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.6+ MB

# %%
mango_reviews = pd.read_csv('./dataset/mango_reviews.csv')
mango_reviews
# Out:
#             store        time  rating  \
# 0    스타벅스 서강대프라자점  2019-10-20       3
# 1      스타벅스 종로관철점  2021-01-27       5
# 2      스타벅스 종로관철점  2018-09-22       3
# 3       스타벅스 등촌역점  2019-03-07       5
# 4      스타벅스 선정릉역점  2020-03-26       5
# ..            ...         ...     ...
# 322      스타벅스 외대점  2015-12-13       5
# 323      스타벅스 외대점  2014-09-21       3
# 324      스타벅스 외대점  2014-07-13       5
# 325  스타벅스 서초이화빌딩점  2019-12-29       3
# 326  스타벅스 서초이화빌딩점  2018-11-04       5
#
#                                                 review
# 0    드디어 주변에만 생기던 스벅이 서강대 교내에도 들어왔습니다! 동네 분들도 생각보다 ...
# 1    이번 새로운 시즌메뉴 더블 에스프레소 크림라떼 존맛탱ㅜㅜ 바닐라 라떼랑 비스무리한데...
# 2                                           요거 타르트 맛이쓔
# 3    발렌타인 프로모션 음료 (화이트초콜릿 어쩌구였음)를 마셨는데 너무 달달하고 맛있었다...
# 4                          트러플머쉬룸 스프!!! 다음번엔 두그릇먹어야겠다.
# ..                                                 ...
# 322  오랜만에 와봤더니 매장 리뉴얼했네요. 예전에는 테이블 디자인 제각각이고 인테리어가 ...
# 323  면적대비 좌석수가 많음에도 불구하고 항상 북적입니다. 주로 공부하는 분들이 많이 찾...
# ...

# %%
mango_reviews[mango_reviews['review'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [store, time, rating, review]
# Index: []

# %%
kakao_reviews[kakao_reviews['review'].duplicated() == True]
# Out:
#      iter_num         store         time  rating review
# 2           2     스타벅스 강남R점  2021.02.03.     5.0   최고예요
# 3           3     스타벅스 강남R점  2020.11.14.     5.0   최고예요
# 6           1     스타벅스 강남R점  2020.09.28.     5.0   최고예요
# 7           2     스타벅스 강남R점  2020.08.22.     5.0   최고예요
# 10          0     스타벅스 강남R점  2020.07.17.     4.0    좋아요
# ...       ...           ...          ...     ...    ...
# 6598        3   스타벅스 묵동이마트점  2017.05.19.     5.0   최고예요
# 6600        1    스타벅스 상일동역점  2021.03.06.     4.0    좋아요
# 6605        2  스타벅스 마리오아울렛점  2018.02.19.     3.0  보통이에요
# 6606        3  스타벅스 마리오아울렛점  2017.04.18.     3.0  보통이에요
# 6607        4  스타벅스 마리오아울렛점  2017.02.06.     4.0    좋아요
#
# [2384 rows x 5 columns]

# %%
naver_reviews[naver_reviews['review'].duplicated() == True]
# Out:
#         user          store        time  rating       review   site
# 10        12  스타벅스 역삼아레나빌딩점  2021.03.19     4.0          좋아요  naver
# 12        14  스타벅스 역삼아레나빌딩점  2021.03.10     4.0          좋아요  naver
# 13        15  스타벅스 역삼아레나빌딩점  2021.03.10     4.0          좋아요  naver
# 14        16  스타벅스 역삼아레나빌딩점  2021.03.10     4.0          좋아요  naver
# 18        20  스타벅스 역삼아레나빌딩점  2021.03.03     4.0          좋아요  naver
# ...      ...            ...         ...     ...          ...    ...
# 123519    95      스타벅스 중화역점  2021.01.01     5.0  #스타벅스 #중화역점  naver
# 123521    97      스타벅스 중화역점  2020.12.31     5.0          좋아요  naver
# 123522    98      스타벅스 중화역점  2020.12.30     5.0         좋아요~  naver
# 123523    99      스타벅스 중화역점  2020.12.29     4.0          좋아요  naver
# 123526   126      스타벅스 중화역점  2020.12.23     5.0       친절해요~~  naver
#
# [68068 rows x 6 columns]
